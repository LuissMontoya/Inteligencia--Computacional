# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
t= np.arange(0,5,0.2)

# %%
plt.plot(t,'ro')

# %%
import cv2

# %% [markdown]
# Cargar una Imagen

# %%
img = np.zeros(shape=(500,500,3),dtype=np.int16)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
pwd
# Out:
# 'C:\\Users\\#Root\\Downloads\\Semestre\\Int Computacional'

# %%
img=cv2.imread('img.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvColor(img,cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-6da6d8cd2249> in <module>
# ----> 1 img = cv2.cvcolor(img,cv2.COLOR_BGR2RGB)
#
# AttributeError: module 'cv2.cv2' has no attribute 'cvcolor'

# %%
img = cv2.imread('img.png', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img)

# %%
img = cv2.imread('img.png')

# %%
norm_img = np.zeros((300, 300))
norm_img = cv2.normalize(img, norm_img, 0, 255, cv2.NORM_MINMAX)

# %%
plt.imshow(norm_img)

# %%
img = cv2.imread('img.png')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
faces_detected = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5)

# %%
plt.imshow(img)

# %%
 img = cv2.cvtColor(img,cv2.COLOR BAYER_BG2 RGB)
# Out:
#   File "<ipython-input-72-e5bab7eeb8f8>", line 1
#     img = cv2.cvtColor(img,cv2.COLOR BAYER_BG2 RGB)
#                                              ^
# SyntaxError: invalid syntax
